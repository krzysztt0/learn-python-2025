# %% [markdown]
# # Python Crash Course - Exercise 09 (draft)
#
# 1. Monte Carlo simulation of coin throw
# 2. Monte Carlo simulation of dice game
# 3. Monte Carlo simulation of computing pi with numpy vs. for loop
# 4. `conda` environment for next lecture: `websoup` (see https://github.com/anastassiavybornova/pythoncrashcourse/blob/main/exercise09_conda.md)
