# %% [markdown]
# # Introduction to Data Science and Programming - Training Exam 2025

# %% [markdown]
# ### General information
# Before you finish, ensure all cells run correctly and output the correct values. Especially, be careful with cells being able to be executed in the correct order in the notebook. Ensure cells all run and don't throw errors.
#
# ### Tasks
# This training exam is like half of a real exam, showing only a data science part. A full exam has 8 tasks in total split into two parts: A programming part and a data science part.
# At most 100 points can be achieved in a full exam. All tasks are designed to be fully solvable with these four packages: `numpy`, `pandas`, `matplotlib` and `networkx`.
#
#
# ### Aids allowed for the exam
# * Written and printed books and notes
# * E-books and/or other electronic devices
# * Calculator
# * The built-in documentation function. E.g., `help(pd.DataFrame.groupby)`
#
# <font color='red'> __Generative AI tools and language models such as ChatGPT, Copilot, Llama3, etc. are not allowed__</font>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

# %% [markdown]
# # Part 1: Basic Python Programming
# [No part 1 in this training exam.]

# %% [markdown]
# ***
# # Part 2: Data Science
#
# For the data science part, ensure that you actually provide the answer to the question with your code. For example, if the task is to find out _"Which political party has the highest number of social media accounts"_, provide both code that shows how you derived the answer and add a comment in your code that specifies which political party it is. E.g. your answer can be something like this:
#
# ```python
# data.groupby(['Political_party']).agg({'Account_ID':'count'})['Account_ID'].nlargest(3)
#  > some results
#  > some results
#  > some results
# # The Lemon party has the most social media accounts
# ```
#
#
# ### Data
# For the data science part you are going to work on two different datasets:
#
# 1. __dataset.csv__: is a dataset based on Twitter usernames of American politicians. The data was extracted from Wikidata. The same politician can appear several times if he/she has different pseudonyms on Twitter or Instagram, if he/she has been in several parties, or if several Twitter account IDs are associated with him/her. But the data is sorted in ascending order by name, so it is visible. This DOES NOT impact your tasks since for most of the analysis (with the exception of 1.5) we will work (and refer to) accounts and not politicians.
# <br/>
#
# 3. __rt_net.tsv__: A graph file of retweeting activity extracted from a twitter dataset. The file contains the network of retweets between users extracted from the dataset_tweet data. Two users are connected if one has retweeted the other (A retweeting B will produce A -> B).

# %% [markdown]
# # Task 5 - Data exploration [15 points]
#
# Here you are going to work with data from dataset.csv.
#
# Make sure to provide the code that allows you to derive the answer.
# For example, if the task is to find out _"Which political party has the highest number of social media accounts"_, provide both code that shows how you derived the answer and add a comment in your code that specifies which political party (e.g. _The Green Party_).

# %% [markdown]
# ### Task 5.1
# Which party has the highest absolute number of “female accounts” ?

# %%
# your code + answer here

# %% [markdown]
# ### Task 5.2
# Who are the youngest and the oldest politicians in the data?

# %%
# your code + answer here

# %% [markdown]
# ### Task 5.3
# Which is the party with the highest number of Instagram accounts?

# %%
# your code + answer here

# %% [markdown]
# ### Task 5.4
# Excluding the United States, which country was the birthplace for the highest number of politicians. Be mindful that politicians can have multiple accounts and appear multiple times in the dataset. We want to avoid double counting.

# %%
# your code + answer here

# %% [markdown]
# ### Task 5.5
# Who is the politician with the highest number of accounts? In te case of a tie, where multiple politicians have the same number, please list them all.

# %%
# your code + answer here

# %% [markdown]
# # Task 6 - Data Manipulation [15 points]

# %% [markdown]
# ### Task 6.1
# Create a new column and call it `account_name_length`. Now, put into the newly created column the length of their `Twitter_username` (number of characters). What is the length of the shortest username, and which politician(s) have accounts with that length of `account_name_length`?

# %%
# your code + answer here

# %% [markdown]
# ### Task 6.2
# Create a new column and call it `age_cat`. Now, using the age of politicians assign one of the following categories: Young (15-24 years), Adult (25-64 years), Senior (65 years and over) to each politician. How many accounts belonging to Senior politicians are present in the data?

# %%
# your code + answer here

# %% [markdown]
# ### Task 6.3
# Create a new dataset containing only the rows where age_cat is `Senior`. In this group, what is the average age for female and male politicians?

# %%
# your code + answer here

# %% [markdown]
# # Task 7 - Data visualization [10 points]

# %% [markdown]
# ### Task 7.1
# Using only the data for the Democratic Party and the Republican Party, visualize the gender composition in the data. Create a bar plot which shows the number of males and females

# %%
# your code + answer here

# %% [markdown]
# ### Task 7.2
# Using the information in of the `Account_start_time` column slice the string to select the year, and visualize how many accounts were created every year.

# %%
# your code + answer here

# %% [markdown]
# # Task 8. Network Science [10 points]
# The file `rt_net.tsv` contains the network of retweets between users extracted from the dataset_tweet data. __It is stored as an edgelist, where users are seperated using a tab (`\t`).__ Two users are connected if one has retweeted the other (A retweeting B will produce A -> B).

# %% [markdown]
# ### Task 8.1
# Load the network as a networkX unidrected Graph and calculate how many nodes, edges, and components there are in the network

# %%
# your code + answer here

# %% [markdown]
# ### Task 8.2
# Calculate both the average degree, and the median degree of all nodes. Round both values to 2 decimal places.

# %%
# your code + answer here

# %% [markdown]
# ### Task 8.3
# Identify the user with the highest degree centrality. Calculate also their degree, how much bigger is their degree compared to the average degree?

# %%
# your code + answer here

# %% [markdown]
# ### Task 8.4
# Reflect on why the average degree is much bigger than the median degree. What do you think caused this? You can either argue for you viewpoints or use code to show why this happens.

# %%
# your reflections or code here
